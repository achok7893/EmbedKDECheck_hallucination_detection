# %% [markdown]
# # EXAMPLE EXECUTION WITH BERT EMBEDDINGS

# %%
# THIS CELL DOWNLOADS THE MODELS
from prejob import download_bert_base
download_bert_base()

# %%
from src.modules.llm_bert import BertEmbeddingModel
import src.modules.embed2kde as embed2kde

bert_model = BertEmbeddingModel(model_name='./data/m_models/bert-base-uncased')

# %%
embed2kde.get_scores_from_input_output_texts("INPUT TEXT", "OUTPUT TEXT", bert_model)

# %% [markdown]
# # EXAMPLE EXECUTION WITH FTW2V

# %%
# THIS CELL DOWNLOAD FTW2V FROM HUGGING FACE
from prejob import download_ftw2v
download_ftw2v()

# %%
import util_embed2kde_ftw2v as util_embed2kde_ftw2v
util_embed2kde_ftw2v.get_prediction_with_embed2kde_ftw2v("TEXTE ENTREE"*15, "TEXTE SORTIE"*15)
