# %%
from src.modules.llm_bert import BertEmbeddingModel
import src.modules.embed2kde as embed2kde

bert_model = BertEmbeddingModel(model_name='./data/m_models/bert-base-uncased')

# %%
embed2kde.get_scores_from_input_output_texts("I am working the day", "I am working the day", bert_model)
# Out:
# {'hallucination_scores': [0.7002706617824095,
#   0.7283864995942548,
#   0.7306215502565504,
#   0.7295027043123878,
#   0.7310585786300049,
#   0.7054798418131077,
#   0.729803600999847],
#  'id_max_hallucination_score': 4,
#  'max_hallucination_score': 0.7310585786300049,
#  'omission_scores': [0.7002706617824095,
#   0.7283864995942548,
#   0.7306215502565504,
#   0.7295027043123878,
#   0.7310585786300049,
#   0.7054798418131077,
#   0.729803600999847],
#  'id_max_omission_score': 4,
#  'max_omission_score': 0.7310585786300049}
